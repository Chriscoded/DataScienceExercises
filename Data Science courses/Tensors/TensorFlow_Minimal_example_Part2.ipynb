# %% [markdown]
# # Minimal example with TensorFlow 2.0
# In this notebook we will recreate our machine learning algorithm using TF 2.0.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# import tensorflow.python.keras as tf_keras

# %% [markdown]
# ## Data generation

# %%
observations = 1000

xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

generated_inputs = np.column_stack((xs,zs))

noise = np.random.uniform(-1, 1, (observations,1))

generated_targets = 2*xs - 3*zs + 5 + noise

np.savez('TF_intro', inputs=generated_inputs, targets=generated_targets)
# print(tf.__version__)

# %% [markdown]
# ## Solving with TensorFlow

# %%
training_data = np.load('TF_intro.npz')

# %%
input_size = 2
output_size = 1

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size)
                            ])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 32/32 - 1s - 23ms/step - loss: 35.8125
# Epoch 2/100
# 32/32 - 0s - 2ms/step - loss: 4.6780
# Epoch 3/100
# 32/32 - 0s - 3ms/step - loss: 1.5704
# Epoch 4/100
# 32/32 - 0s - 3ms/step - loss: 0.6862
# Epoch 5/100
# 32/32 - 0s - 2ms/step - loss: 0.4324
# Epoch 6/100
# 32/32 - 0s - 3ms/step - loss: 0.3724
# Epoch 7/100
# 32/32 - 0s - 2ms/step - loss: 0.3594
# Epoch 8/100
# 32/32 - 0s - 2ms/step - loss: 0.3525
# Epoch 9/100
# 32/32 - 0s - 2ms/step - loss: 0.3541
# Epoch 10/100
# 32/32 - 0s - 3ms/step - loss: 0.3579
# Epoch 11/100
# 32/32 - 0s - 3ms/step - loss: 0.3528
# Epoch 12/100
# 32/32 - 0s - 3ms/step - loss: 0.3531
# Epoch 13/100
# 32/32 - 0s - 3ms/step - loss: 0.3488
# Epoch 14/100
# 32/32 - 0s - 2ms/step - loss: 0.3578
# Epoch 15/100
# 32/32 - 0s - 4ms/step - loss: 0.3490
# Epoch 16/100
# 32/32 - 0s - 2ms/step - loss: 0.3552
# Epoch 17/100
# 32/32 - 0s - 3ms/step - loss: 0.3494
# Epoch 18/100
# 32/32 - 0s - 3ms/step - loss: 0.3553
# Epoch 19/100
# 32/32 - 0s - 3ms/step - loss: 0.3491
# Epoch 20/100
# 32/32 - 0s - 2ms/step - loss: 0.3496
# Epoch 21/100
# 32/32 - 0s - 3ms/step - loss: 0.3555
# Epoch 22/100
# 32/32 - 0s - 3ms/step - loss: 0.3515
# Epoch 23/100
# 32/32 - 0s - 2ms/step - loss: 0.3505
# Epoch 24/100
# 32/32 - 0s - 2ms/step - loss: 0.3501
# Epoch 25/100
# 32/32 - 0s - 3ms/step - loss: 0.3464
# Epoch 26/100
# 32/32 - 0s - 3ms/step - loss: 0.3517
# Epoch 27/100
# 32/32 - 0s - 3ms/step - loss: 0.3547
# Epoch 28/100
# 32/32 - 0s - 3ms/step - loss: 0.3516
# Epoch 29/100
# 32/32 - 0s - 3ms/step - loss: 0.3489
# Epoch 30/100
# 32/32 - 0s - 2ms/step - loss: 0.3473
# Epoch 31/100
# 32/32 - 0s - 2ms/step - loss: 0.3545
# Epoch 32/100
# 32/32 - 0s - 3ms/step - loss: 0.3516
# Epoch 33/100
# 32/32 - 0s - 3ms/step - loss: 0.3577
# Epoch 34/100
# 32/32 - 0s - 3ms/step - loss: 0.3433
# Epoch 35/100
# 32/32 - 0s - 3ms/step - loss: 0.3533
# Epoch 36/100
# 32/32 - 0s - 3ms/step - loss: 0.3530
# Epoch 37/100
# 32/32 - 0s - 3ms/step - loss: 0.3554
# Epoch 38/100
# 32/32 - 0s - 4ms/step - loss: 0.3553
# Epoch 39/100
# 32/32 - 0s - 2ms/step - loss: 0.3531
# Epoch 40/100
# 32/32 - 0s - 3ms/step - loss: 0.3525
# Epoch 41/100
# 32/32 - 0s - 3ms/step - loss: 0.3460
# Epoch 42/100
# 32/32 - 0s - 3ms/step - loss: 0.3474
# Epoch 43/100
# 32/32 - 0s - 3ms/step - loss: 0.3579
# Epoch 44/100
# 32/32 - 0s - 3ms/step - loss: 0.3550
# Epoch 45/100
# 32/32 - 0s - 3ms/step - loss: 0.3515
# Epoch 46/100
# 32/32 - 0s - 3ms/step - loss: 0.3494
# Epoch 47/100
# 32/32 - 0s - 3ms/step - loss: 0.3478
# Epoch 48/100
# 32/32 - 0s - 3ms/step - loss: 0.3416
# Epoch 49/100
# 32/32 - 0s - 2ms/step - loss: 0.3538
# Epoch 50/100
# 32/32 - 0s - 2ms/step - loss: 0.3490
# Epoch 51/100
# 32/32 - 0s - 3ms/step - loss: 0.3534
# Epoch 52/100
# 32/32 - 0s - 4ms/step - loss: 0.3538
# Epoch 53/100
# 32/32 - 0s - 3ms/step - loss: 0.3487
# Epoch 54/100
# 32/32 - 0s - 3ms/step - loss: 0.3553
# Epoch 55/100
# 32/32 - 0s - 3ms/step - loss: 0.3531
# Epoch 56/100
# 32/32 - 0s - 2ms/step - loss: 0.3498
# Epoch 57/100
# 32/32 - 0s - 2ms/step - loss: 0.3545
# Epoch 58/100
# 32/32 - 0s - 3ms/step - loss: 0.3502
# Epoch 59/100
# 32/32 - 0s - 3ms/step - loss: 0.3512
# Epoch 60/100
# 32/32 - 0s - 3ms/step - loss: 0.3532
# Epoch 61/100
# 32/32 - 0s - 4ms/step - loss: 0.3456
# Epoch 62/100
# 32/32 - 0s - 3ms/step - loss: 0.3531
# Epoch 63/100
# 32/32 - 0s - 3ms/step - loss: 0.3536
# Epoch 64/100
# 32/32 - 0s - 3ms/step - loss: 0.3588
# Epoch 65/100
# 32/32 - 0s - 4ms/step - loss: 0.3488
# Epoch 66/100
# 32/32 - 0s - 2ms/step - loss: 0.3515
# Epoch 67/100
# 32/32 - 0s - 3ms/step - loss: 0.3490
# Epoch 68/100
# 32/32 - 0s - 3ms/step - loss: 0.3557
# Epoch 69/100
# 32/32 - 0s - 3ms/step - loss: 0.3500
# Epoch 70/100
# 32/32 - 0s - 3ms/step - loss: 0.3502
# Epoch 71/100
# 32/32 - 0s - 2ms/step - loss: 0.3476
# Epoch 72/100
# 32/32 - 0s - 3ms/step - loss: 0.3507
# Epoch 73/100
# 32/32 - 0s - 2ms/step - loss: 0.3540
# Epoch 74/100
# 32/32 - 0s - 2ms/step - loss: 0.3520
# Epoch 75/100
# 32/32 - 0s - 4ms/step - loss: 0.3494
# Epoch 76/100
# 32/32 - 0s - 3ms/step - loss: 0.3584
# Epoch 77/100
# 32/32 - 0s - 3ms/step - loss: 0.3572
# Epoch 78/100
# 32/32 - 0s - 3ms/step - loss: 0.3536
# Epoch 79/100
# 32/32 - 0s - 3ms/step - loss: 0.3550
# Epoch 80/100
# 32/32 - 0s - 2ms/step - loss: 0.3559
# Epoch 81/100
# 32/32 - 0s - 3ms/step - loss: 0.3527
# Epoch 82/100
# 32/32 - 0s - 3ms/step - loss: 0.3487
# Epoch 83/100
# 32/32 - 0s - 3ms/step - loss: 0.3569
# Epoch 84/100
# 32/32 - 0s - 3ms/step - loss: 0.3495
# Epoch 85/100
# 32/32 - 0s - 2ms/step - loss: 0.3494
# Epoch 86/100
# 32/32 - 0s - 3ms/step - loss: 0.3503
# Epoch 87/100
# 32/32 - 0s - 2ms/step - loss: 0.3586
# Epoch 88/100
# 32/32 - 0s - 2ms/step - loss: 0.3519
# Epoch 89/100
# 32/32 - 0s - 3ms/step - loss: 0.3556
# Epoch 90/100
# 32/32 - 0s - 3ms/step - loss: 0.3466
# Epoch 91/100
# 32/32 - 0s - 3ms/step - loss: 0.3464
# Epoch 92/100
# 32/32 - 0s - 2ms/step - loss: 0.3489
# Epoch 93/100
# 32/32 - 0s - 3ms/step - loss: 0.3505
# Epoch 94/100
# 32/32 - 0s - 3ms/step - loss: 0.3503
# Epoch 95/100
# 32/32 - 0s - 2ms/step - loss: 0.3525
# Epoch 96/100
# 32/32 - 0s - 3ms/step - loss: 0.3486
# Epoch 97/100
# 32/32 - 0s - 2ms/step - loss: 0.3497
# Epoch 98/100
# 32/32 - 0s - 2ms/step - loss: 0.3539
# Epoch 99/100
# 32/32 - 0s - 3ms/step - loss: 0.3528
# Epoch 100/100
# 32/32 - 0s - 2ms/step - loss: 0.3430
